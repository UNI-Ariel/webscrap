# %%
from bs4 import BeautifulSoup
import requests

# Obtener el contenido de la pagina
# Esta pagina necesita establecer el encoding a utf-8
res =  requests.get("http://localhost:8080/html/Tu%20real%20en%20black%20friday%20_%20Dismac.html")
res.encoding = "UTF-8"
page = res.text
soup = BeautifulSoup(page, "lxml")

# Mostrar el contenido
str(soup)[:500]
# Out:
# '<!DOCTYPE html>\n<!-- saved from url=(0329)https://www.dismac.com.bo/tu-real-en-black-friday/categoria_filter_audiomenor-categoria_filter_computacion-categoria_filter_hogarinteligente-categoria_filter_oficina-categoria_filter_telefonia-categoria_filter_videojuegos.html?utm_source=direct&utm_medium=category-card&utm_campaign=tu-real-en-black-friday&utm_content=tecnologia --><html lang="es"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n<script async="" src="./Tu real en'

# %%
# Realizar la exploración de la pagina y armar estructura
# El elemento de interes se encuentra en un div con clase "product-item-pdc"
items = soup.find_all("div", {"class": "product-item-pdc"})

# Mostrar los itms
str(items)[:500]
# Out:
# '[<div class="product-item-pdc" data-view="grid-view" id="185297-product-item">\n<div class="content-product-image" id="185297-product-item">\n<a href="https://www.dismac.com.bo/altavoz-inalambrico-portatil-sony-ult-field-1-color-blancosrs-ult10-wcla.html" title="Altavoz inalámbrico Portátil Sony ULT FIELD 1 color Blanco">\n<img alt="Altavoz inalámbrico Portátil Sony ULT FIELD 1 color Blanco" loading="lazy" src="./Tu real en black friday _ Dismac_files/2_1328.jpg"/>\n</a>\n<div class="oportunidad-unic'

# %%
# El nombre del producto esta en un div con clase "width-section-name"
# E internamente dentro un span con class "name"
for prod in items:
  p = prod.find("span", {"class": "name"})
  print(p)
# Out:
# <span class="name">Altavoz inalámbrico Portátil Sony ULT FIELD 1 color Blanco</span>
# <span class="name">Combo Monitor Plano Master-G 22" Full HD 75Hz + Audífonos Philips intrauditivos con cable Azul</span>
# <span class="name">Computadora Portátil Asus Vivobook Go14 Celeron N4500 14" (4+ 128GB) Win11 color Estrella Negra</span>
# <span class="name">Consola NINTENDO Switch 1.1 Neon + Juego Super Mario Bros. Wonder</span>
# <span class="name">Consola Nintendo Switch OLED + Control Joy-Con Blanco Super Mario Bros</span>
# <span class="name">Impresora Multifuncional HP Smart Tank 520</span>
# <span class="name">Monitor Acer Gaming VG240Y M3BIIP 24" Full HD 1920x1080</span>
# <span class="name">Parlante portátil inalámbrico Sony ULT FIELD 3 color Blanco</span>
# <span class="name">Parlante portátil inalámbrico Sony ULT FIELD 3 color Gris</span>
# <span class="name">Parlante portátil inalámbrico Sony ULT FIELD 3 color Negro</span>
# <span class="name">Tablet Redbeat PAD C1 8" (3+ 64GB) + Funda color Negro 2BGTO-C1</span>
# <span class="name">Telefono celular INFINIX SMART 10 (3+ 64GB) color Iris azul</span>
# <span class="name">Teléfono Celular INFINIX HOT 60I (4+ 256GB) color Sombra Azul</span>
# <span class="name">Teléfono Celular INFINIX SMART 10 (3+ 64GB) color Negro elegante</span>
# <span class="name">Teléfono celular HONOR 400 Lite (8+ 256GB) color Tercipelo Negro</span>
# <span class="name">Teléfono celular HONOR 400 Lite (8+ 256GB) color Verde marino</span>
# <span class="name">Teléfono celular HONOR X6c (6+ 256GB) color Cian océano</span>
# <span class="name">Teléfono celular Xiaomi Redmi 15C (4+ 128GB) color Azul de Luna</span>
# <span class="name">Combo Teléfono celular Samsung Galaxy A26 (8+256 GB) color Negro + Funda Samsung para A26 con tarjetero color Negro</span>
# <span class="name">Combo Teléfono celular Samsung Galaxy A56 (8 +256GB) color Negro + Funda Samsung para A56 con tarjetero color Negro</span>

# %%
# Los precios se encuentran en un div con clase "section-widget-price"
# E internamente en un span con clase "current-price"
for prod in items:
  p = prod.find("span", {"class": "current-price"})
  print(p)
# Out:
# <span class="current-price">Bs. 1,099.00</span>
# <span class="current-price">Bs. 1,399.00</span>
# <span class="current-price">Bs. 3,799.00</span>
# <span class="current-price">Bs. 4,999.00</span>
# <span class="current-price">Bs. 5,999.00</span>
# <span class="current-price">Bs. 2,589.00</span>
# <span class="current-price">Bs. 1,999.00</span>
# <span class="current-price">Bs. 1,999.00</span>
# <span class="current-price">Bs. 1,999.00</span>
# <span class="current-price">Bs. 1,999.00</span>
# <span class="current-price">Bs. 1,399.00</span>
# <span class="current-price">Bs. 1,199.00</span>
# <span class="current-price">Bs. 1,769.00</span>
# <span class="current-price">Bs. 1,199.00</span>
# <span class="current-price">Bs. 3,899.00</span>
# <span class="current-price">Bs. 3,899.00</span>
# <span class="current-price">Bs. 1,999.00</span>
# <span class="current-price">Bs. 1,949.00</span>
# <span class="current-price">Bs. 4,249.00</span>
# <span class="current-price">Bs. 5,599.00</span>

# %%
# Finalmente los datos de interes son
datos = dict()
for prod in items:
  titulo = prod.find("span", {"class": "name"}).text
  precio = prod.find("span", {"class": "current-price"}).text
  print(f"titulo: {titulo}, precio: {precio}")
# Out:
# titulo: Altavoz inalámbrico Portátil Sony ULT FIELD 1 color Blanco, precio: Bs. 1,099.00
# titulo: Combo Monitor Plano Master-G 22" Full HD 75Hz + Audífonos Philips intrauditivos con cable Azul, precio: Bs. 1,399.00
# titulo: Computadora Portátil Asus Vivobook Go14 Celeron N4500 14" (4+ 128GB) Win11 color Estrella Negra, precio: Bs. 3,799.00
# titulo: Consola NINTENDO Switch 1.1 Neon + Juego Super Mario Bros. Wonder, precio: Bs. 4,999.00
# titulo: Consola Nintendo Switch OLED + Control Joy-Con Blanco Super Mario Bros, precio: Bs. 5,999.00
# titulo: Impresora Multifuncional HP Smart Tank 520, precio: Bs. 2,589.00
# titulo: Monitor Acer Gaming VG240Y M3BIIP 24" Full HD 1920x1080, precio: Bs. 1,999.00
# titulo: Parlante portátil inalámbrico Sony ULT FIELD 3 color Blanco, precio: Bs. 1,999.00
# titulo: Parlante portátil inalámbrico Sony ULT FIELD 3 color Gris, precio: Bs. 1,999.00
# titulo: Parlante portátil inalámbrico Sony ULT FIELD 3 color Negro, precio: Bs. 1,999.00
# titulo: Tablet Redbeat PAD C1 8" (3+ 64GB) + Funda color Negro 2BGTO-C1, precio: Bs. 1,399.00
# titulo: Telefono celular INFINIX SMART 10 (3+ 64GB) color Iris azul, precio: Bs. 1,199.00
# titulo: Teléfono Celular INFINIX HOT 60I (4+ 256GB) color Sombra Azul, precio: Bs. 1,769.00
# titulo: Teléfono Celular INFINIX SMART 10 (3+ 64GB) color Negro elegante, precio: Bs. 1,199.00
# titulo: Teléfono celular HONOR 400 Lite (8+ 256GB) color Tercipelo Negro, precio: Bs. 3,899.00
# titulo: Teléfono celular HONOR 400 Lite (8+ 256GB) color Verde marino, precio: Bs. 3,899.00
# titulo: Teléfono celular HONOR X6c (6+ 256GB) color Cian océano, precio: Bs. 1,999.00
# titulo: Teléfono celular Xiaomi Redmi 15C (4+ 128GB) color Azul de Luna, precio: Bs. 1,949.00
# titulo: Combo Teléfono celular Samsung Galaxy A26 (8+256 GB) color Negro + Funda Samsung para A26 con tarjetero color Negro, precio: Bs. 4,249.00
# titulo: Combo Teléfono celular Samsung Galaxy A56 (8 +256GB) color Negro + Funda Samsung para A56 con tarjetero color Negro, precio: Bs. 5,599.00
